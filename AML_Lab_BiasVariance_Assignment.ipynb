# %% [markdown]
# <a href="https://colab.research.google.com/github/VaibhaviDeveloper/MSIS_AML/blob/main/AML_Lab_BiasVariance_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import os
os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'data-1.csv',
#  'Kaagaz_20220914_141308009993.pdf',
#  'Kaagaz_20220914_141308009993.gdoc',
#  'Untitled presentation (4).gslides',
#  'Untitled presentation (3).gslides',
#  'Untitled presentation (2).gslides',
#  'Untitled presentation (1).gslides',
#  'Untitled presentation.gslides',
#  'Untitled form (1).gform',
#  'Untitled form.gform',
#  'AmazonLogo.jpg',
#  'SignIn.jpg',
#  'E-Commerce.html',
#  'SignUp.html',
#  'SignIn.html',
#  'Forgot.html',
#  'Successful.html',
#  'style (1).css',
#  'StripLight.jpg',
#  'hero-img.jpg',
#  'style2.css',
#  'Laptop.jpg',
#  'Smartwatch.jpg',
#  'RoomFreshner.jpg',
#  'signup.html',
#  'signin.html',
#  'forgot.html',
#  'twoa.html',
#  'styletwo.css',
#  'style.css',
#  'successfull.html',
#  'AmazonImage.jpg',
#  'ScrollinBlinking.html',
#  "Vaibhavi's Resume.pdf",
#  "Vaibhavi's Resume (1).gdoc",
#  "Vaibhavi's Resume.gdoc",
#  'nnm22cs195.pdf',
#  'Vaibhavi N-Resume (3).pdf',
#  'Sambhram Permission.gdoc',
# ...

# %%
data = pd.read_csv('/content/drive/MyDrive/data-1.csv')

# %%
data.head()
# Out:
#    offer  Age  online payment  items
# 0      1   35               0      5
# 1      1   26               0      4
# 2      1   41               0      9
# 3      1   34               0     10
# 4      1   38               0      3

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
selector = VarianceThreshold(threshold=0.0)
X_selected = selector.fit_transform(data)
selected_columns = data.columns[selector.get_support()]
print("Selected Columns:",list(selected_columns))
# Out:
# Selected Columns: ['Age', 'items']

# %%
data2 = pd.read_csv('/content/drive/MyDrive/data-2.csv')

# %%
selector = VarianceThreshold(threshold=0.0)
X_selected = selector.fit_transform(data2)
selected_columns = data2.columns[selector.get_support()]
print("Selected Columns:",list(selected_columns))
# Out:
# Selected Columns: ['referred', 'repeat', 'Age', 'Promoted', 'items']

# %%
data2.head()
# Out:
#    referred  repeat  Age  Promoted  items
# 0         1       0   35         1      5
# 1         0       0   26         0      4
# 2         1       0   41         1      9
# 3         1       1   34         0     10
# 4         1       0   38         1      3

# %%
selector = VarianceThreshold(threshold=0.5)
X_selected = selector.fit_transform(data2)
selected_columns = data2.columns[selector.get_support()]
print("Selected Columns:",list(selected_columns))
# Out:
# Selected Columns: ['Age', 'items']
