# %% [markdown]
# <a href="https://colab.research.google.com/github/VaibhaviDeveloper/MSIS_AML/blob/main/SalaryLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'Kaagaz_20220914_141308009993.pdf',
#  'Kaagaz_20220914_141308009993.gdoc',
#  'Untitled presentation (4).gslides',
#  'Untitled presentation (3).gslides',
#  'Untitled presentation (2).gslides',
#  'Untitled presentation (1).gslides',
#  'Untitled presentation.gslides',
#  'Untitled form (1).gform',
#  'Untitled form.gform',
#  'AmazonLogo.jpg',
#  'SignIn.jpg',
#  'E-Commerce.html',
#  'SignUp.html',
#  'SignIn.html',
#  'Forgot.html',
#  'Successful.html',
#  'style (1).css',
#  'StripLight.jpg',
#  'hero-img.jpg',
#  'style2.css',
#  'Laptop.jpg',
#  'Smartwatch.jpg',
#  'RoomFreshner.jpg',
#  'signup.html',
#  'signin.html',
#  'forgot.html',
#  'twoa.html',
#  'styletwo.css',
#  'style.css',
#  'successfull.html',
#  'AmazonImage.jpg',
#  'ScrollinBlinking.html',
#  "Vaibhavi's Resume.pdf",
#  "Vaibhavi's Resume (1).gdoc",
#  "Vaibhavi's Resume.gdoc",
#  'nnm22cs195.pdf',
#  'Vaibhavi N-Resume (3).pdf',
#  'Sambhram Permission.gdoc',
# ...

# %%
df=pd.read_csv('/content/drive/MyDrive/Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X=df.drop('Salary',axis=1)
y=df['Salary']

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
)

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

# %%
print("MAE :",mae)
# Out:
# MAE : 2446.1723690465055

# %%
print("MSE" , mse)
# Out:
# MSE 12823412.298126549

# %%
print("r2_score" , r2)
# Out:
# r2_score 0.988169515729126

# %%
print("RMSE :",rmse)
# Out:
# RMSE : 3580.979237321343

# %%
print("Model Accuracy :",regressor.score(X_test,y_test))
# Out:
# Model Accuracy : 0.988169515729126

# %%
plt.scatter(y_test,y_pred,color="blue")
minimum=min(y_test.min(),y_pred.min())
maximum=max(y_test.max(),y_pred.max())
plt.plot([minimum,maximum],[minimum,maximum],color="red",linestyle="--")
plt.xlabel("Actual Salary")
plt.ylabel("Predicted Salary")
plt.title("Actual vs Predicted Salary")
plt.show()

# %%
residuals=y_test-y_pred
plt.scatter(y_pred,residuals,color="blue")
plt.axhline(y=0,color="red",linestyle="--")
plt.xlabel("Predicted Salary")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
